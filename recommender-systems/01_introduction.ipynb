# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/PreferredAI/tutorials/blob/master/recommender-systems/01_introduction.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/PreferredAI/tutorials/blob/master/recommender-systems/01_introduction.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# # Introduction
#
# In this first foray into recommender systems, we explore a popular recommendation dataset called MovieLens, studying its distributions of users, items, and ratings.  We then apply a basic yet commonly effective recommendation strategy based on item popularity.

# %% [markdown]
# ## 1. Setup

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: cornac in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 1)) (2.3.5)
# Requirement already satisfied: numpy in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 2)) (2.4.4)
# Collecting pandas (from -r requirements.txt (line 3))
#   Downloading pandas-3.0.2-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# Requirement already satisfied: matplotlib in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from -r requirements.txt (line 4)) (3.10.8)
# Collecting seaborn (from -r requirements.txt (line 5))
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn (from -r requirements.txt (line 6))
#   Downloading scikit_learn-1.8.0-cp314-cp314-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: scipy in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from cornac->-r requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: tqdm in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from cornac->-r requirements.txt (line 1)) (4.67.3)
# Requirement already satisfied: powerlaw in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from cornac->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from pandas->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 4)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 4)) (26.1)
# Requirement already satisfied: pillow>=8 in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 4)) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from matplotlib->-r requirements.txt (line 4)) (3.3.2)
# Collecting joblib>=1.3.0 (from scikit-learn->-r requirements.txt (line 6))
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn->-r requirements.txt (line 6))
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: mpmath in /Users/yudhistiraonggowarsito/Documents/SMU/Courses/CS608 - Recommender Systems/.venv/lib/python3.14/site-packages (from powerlaw->cornac->-r requirements.txt (line 1)) (1.4.1)
# Downloading pandas-3.0.2-cp314-cp314-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 1.8 MB/s  0:00:05m 1.6 MB/s eta 0:00:01
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading scikit_learn-1.8.0-cp314-cp314-macosx_12_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 4.8 MB/s  0:00:01m 4.0 MB/s eta 0:00:01
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn, pandas, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [seaborn]━━━ 3/5 [pandas]learn]
# Successfully installed joblib-1.5.3 pandas-3.0.2 scikit-learn-1.8.0 seaborn-0.13.2 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import sys

import cornac
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats, sparse

# %matplotlib inline

print(f"System version: {sys.version}")
print(f"Cornac version: {cornac.__version__}")
# Out:
# System version: 3.14.3 (main, Feb  3 2026, 15:32:20) [Clang 17.0.0 (clang-1700.6.3.2)]
# Cornac version: 2.3.5

# %% [markdown]
# ## 2. Data Exploration
#
# We begin by exploring [MovieLens](https://grouplens.org/datasets/movielens/), which is a popular benchmark dataset used in many studies on recommender systems.  There are several variants of different sizes, i.e., 100K, 1M, 10M, and 20M.  For the purpose of demonstration, we start with the smallest one with 100K ratings.  This dataset is built into and can be loaded from within the Cornac library, which also contains [other datasets](https://github.com/PreferredAI/cornac/blob/master/cornac/datasets/README.md) as well.
#
# Most of the time we will see each instance in a recommendation dataset being represented in the form of a triplet (*user_id*, *item_id*, *rating*).  For this MovieLens dataset, the rating values are in the range {1, 2, 3, 4, 5}.

# %%
data = cornac.datasets.movielens.load_feedback(variant="20M")
df = pd.DataFrame(data, columns=["user_id", "item_id", "rating"])
df.head()
# Out:
# Data from http://files.grouplens.org/datasets/movielens/ml-20m.zip
# will be cached into /Users/yudhistiraonggowarsito/.cornac/ml-20m/ratings.csv
# 199MB [01:32, 2.16MB/s]
# Unzipping ...
# File cached!
#   user_id item_id  rating
# 0       1       2     3.5
# 1       1      29     3.5
# 2       1      32     3.5
# 3       1      47     3.5
# 4       1      50     3.5

# %%
print(f"Number of ratings: {len(df)}")
print(f"Number of users: {df.user_id.nunique()}")
print(f"Number of items: {df.item_id.nunique()}")
# Out:
# Number of ratings: 20000263
# Number of users: 138493
# Number of items: 26744

# %% [markdown]
# ### Rating Statistics
#
# Let's see some basic statistics of the rating values.

# %%
df.rating.describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %% [markdown]
# We can plot these rating values to see how it's being distributed.
#
# *   The 1st figure below shows a histogram of the frequency of each rating.
# *   The 2nd figure describes the same distribution in the form of box plot.
#
# Generally, more than 50% of the rating values lie between {3, 4}, rating 5 is also common, while {1, 2} are less likely.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
sns.countplot(x="rating", hue="rating", data=df, palette="ch:.25", ax=axes[0], legend=False)
sns.boxplot(x="rating", data=df, ax=axes[1])
# Out:
# <Axes: xlabel='rating'>

# %% [markdown]
# ### Data Sparsity
#
# Data sparsity is a measure of how much data we do *not* observe.  It is generally a challenge in learning from data.  The concern is whether we have sufficient information to build a model that can accurately capture the general distribution of the data.
#
# For recommender systems in particular, data sparsity is expressed as the number of missing ratings divided by the total number of possible ratings.  This total is the number of users multiplied by the number of items.  In many recommendation datasets, a user only gives ratings to a limited number of items.

# %%
n_users = df.user_id.nunique()
n_items = df.item_id.nunique()
n_ratings = len(df)
rating_matrix_size = n_users * n_items
sparsity = 1 - n_ratings / rating_matrix_size

print(f"Number of users: {n_users}")
print(f"Number of items: {n_items}")
print(f"Number of available ratings: {n_ratings}")
print(f"Number of all possible ratings: {rating_matrix_size}")
print("-" * 40)
print(f"SPARSITY: {sparsity * 100.0:.2f}%")
# Out:
# Number of users: 138493
# Number of items: 26744
# Number of available ratings: 20000263
# Number of all possible ratings: 3703856792
# ----------------------------------------
# SPARSITY: 99.46%

# %% [markdown]
# For this MovieLens dataset, the data has been prepared in such a way that each user has at least 20 ratings. As a result, it's relatively dense as compared to many other recommendation datasets that are usually much sparser (often 99% or more).

# %% [markdown]
# ### Power-Law Distribution
#
# In recommendation, another important phenomenom is a [power-law/long-tailed distribution](https://en.wikipedia.org/wiki/Power_law).  It implies that some of the items are very popular and frequently rated by users, while most of the other items are rated by very few users.
#
# First, we count the number of ratings by item.  Shown below are the top 10 rated items.

# %%
item_rate_count = df.groupby("item_id")["user_id"].nunique().sort_values(ascending=False)
item_rate_count.head(10)
# Out:
# item_id
# 296     67310
# 356     66172
# 318     63366
# 593     63299
# 480     59715
# 260     54502
# 110     53769
# 589     52244
# 2571    51334
# 527     50054
# Name: user_id, dtype: int64

# %% [markdown]
# For contrast, let's see the list of 10 least rated items.  All of them are only rated by 1 user.

# %%
item_rate_count.tail(10)
# Out:
# item_id
# 110613    1
# 88543     1
# 124775    1
# 124779    1
# 110601    1
# 110599    1
# 124793    1
# 110584    1
# 79741     1
# 47250     1
# Name: user_id, dtype: int64

# %% [markdown]
# Below we visualize the rating count information.
#
# *   The 1st figure shows the number of ratings of each item. Items are sorted in descending values of the rating counts. Thus, the most popular item are leftmost.  The long-tailed shape discussed earlier is evident.
# *   The 2nd figure is the [log-log plot](https://en.wikipedia.org/wiki/Log%E2%80%93log_plot) showing the relationship between the number of ratings and the number of items (both in log scale).   The relationship is asymptotically linear, which is the main characteristic of a power-law distribution.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))

axes[0].bar(x=item_rate_count.index, height=item_rate_count.values, width=1.0, align="edge")
axes[0].set_xticks([])
axes[0].set(title="long tail of rating frequency",
            xlabel="item ordered by decreasing frequency",
            ylabel="#ratings")

count = item_rate_count.value_counts()
sns.scatterplot(x=np.log(count.index), y=np.log(count.values), ax=axes[1])
axes[1].set(title="log-log plot", xlabel="#ratings (log scale)", ylabel="#items (log scale)");

# %% [markdown]
# ## 3. Recommendation Based on Item Popularity
#
# Since some items are much more popular than the rest, intuitively many users may prefer these popular items.  From that observation, it inspires a simple approach for providing recommendations based on popularity (i.e., number of ratings) of the items.
#
# Let's do a simple experiment with the popularity approach.  In this experiment, we will split the rating data into 5 folds for cross-validation.  For each run, 4 folds will be used for training and the remaining fold will be used for evaluation.  We measure the recommendation performance using Recall@20 metric.

# %%
# 5-fold cross validation
eval_method = cornac.eval_methods.CrossValidation(data, n_folds=5, seed=42)

# recommender system based on item popularity
most_pop = cornac.models.MostPop()

# recall@20 metric
rec_20 = cornac.metrics.Recall(k=20)

# put everything together into an experiment
cornac.Experiment(eval_method=eval_method, models=[most_pop], metrics=[rec_20], save_dir=None).run()
# Out:
# TEST:
# ...
# [MostPop]
#        | Recall@20 | Train (s) | Test (s)
# ------ + --------- + --------- + --------
# Fold 0 |    0.1228 |    0.1560 |  33.9333
# Fold 1 |    0.1231 |    0.1027 |  34.1487
# Fold 2 |    0.1231 |    0.1560 |  35.0500
# Fold 3 |    0.1238 |    0.1447 |  34.9147
# Fold 4 |    0.1226 |    0.2238 |  34.9443
# ------ + --------- + --------- + --------
# Mean   |    0.1231 |    0.1566 |  34.5982
# Std    |    0.0004 |    0.0389 |   0.4622
